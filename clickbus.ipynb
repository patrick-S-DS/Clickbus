# %%
import pandas as pd
import re

# %%
pd.options.display.max_columns= 25

# %%
click = pd.read_csv(r"C:\Users\petri\Downloads\dados-Dashboard.csv", encoding= 'latin-1', sep=';', thousands=',')
click
# Out:
#           Data GMV Desktop Realizado GMV Desktop Meta GMV Mobile Realizado  \
# 0   01/08/2019          R$423,154.38     R$423,562.06         R$859,131.62
# 1   02/08/2019          R$610,986.60     R$488,932.62         R$843,743.40
# 2   03/08/2019          R$802,752.09     R$504,307.76         R$605,584.91
# 3   04/08/2019          R$647,502.90     R$492,976.05         R$529,775.10
# 4   05/08/2019          R$527,546.40     R$443,841.60         R$619,293.60
# 5   06/08/2019          R$633,628.78     R$481,623.57         R$561,897.22
# 6   07/08/2019          R$548,082.90     R$494,727.30         R$669,879.10
# 7   08/08/2019          R$557,599.50     R$528,407.88         R$557,599.50
# 8   09/08/2019          R$616,812.84     R$613,905.48         R$525,433.16
# 9   10/08/2019          R$555,358.05     R$409,196.88         R$678,770.95
# 10  11/08/2019          R$770,719.11     R$632,567.16         R$683,467.89
# ...

# %%
click.columns
# Out:
# Index(['Data', 'GMV Desktop Realizado', 'GMV Desktop Meta',
#        'GMV Mobile Realizado', 'GMV Mobile Meta', 'Vendas Desktop Realizado',
#        'Vendas Desktop Meta', 'Vendas Mobile Realizado', 'Vendas Mobile Meta',
#        'Vendas Totais com Desconto', 'Visitas Desktop', 'Visitas Mobile',
#        'Clientes Desktop', 'Clientes Mobile', 'Novos Clientes Desktop',
#        'Novos Clientes Mobile', 'Rotas Distintas Vendidas',
#        'Viações Distintas Vendidas', 'Custo de Marketing Desktop',
#        'Custo de Marketing Mobile', 'Vendas Bloqueadas Anti-Fraude Desktop',
#        'Vendas Bloqueadas Anti-Fraude Mobile'],
#       dtype='object')

# %%
click.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Data                                   31 non-null     object
#  1   GMV Desktop Realizado                  31 non-null     object
#  2   GMV Desktop Meta                       31 non-null     object
#  3   GMV Mobile Realizado                   31 non-null     object
#  4   GMV Mobile Meta                        31 non-null     object
#  5   Vendas Desktop Realizado               31 non-null     int64
#  6   Vendas Desktop Meta                    31 non-null     int64
#  7   Vendas Mobile Realizado                31 non-null     int64
#  8   Vendas Mobile Meta                     31 non-null     int64
#  9   Vendas Totais com Desconto             31 non-null     int64
#  10  Visitas Desktop                        31 non-null     int64
# ...

# %%
click.to_csv(r"C:\Users\petri\Downloads\clickbus\dados_click.csv", index=False)
